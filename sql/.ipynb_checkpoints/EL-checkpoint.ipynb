# %%
from sqlalchemy import create_engine

server = "laptop-t5cbj27g\SQLEXPRESS"
database = "Bluestock_MF"

engine = create_engine(
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
    "&trusted_connection=yes"
)

print("Connected Successfully")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22784\4091406864.py:3: SyntaxWarning: invalid escape sequence '\S'
#   server = "laptop-t5cbj27g\SQLEXPRESS"
# Connected Successfully

# %%
pip install sqlalchemy pyodbc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
server = "laptop-t5cbj27g\SQLEXPRESS"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22784\93725823.py:1: SyntaxWarning: invalid escape sequence '\S'
#   server = "laptop-t5cbj27g\SQLEXPRESS"

# %%
import pandas as pd
fund_master = pd.read_csv(
    r"C:/Users/Admin/Desktop/Mutual_Fund_Analysis/data/processed/01_fund_master.csv"
)

# %%
fund_master.to_sql(
    "dim_fund",
    con=engine,
    if_exists="append",
    index=False
)

print("dim_fund loaded")
# Out:
# dim_fund loaded
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:1636: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   con = self.exit_stack.enter_context(con.connect())

# %%
import pandas as pd

nav = pd.read_csv(r"C:/Users/Admin/Desktop/Mutual_Fund_Analysis/data/processed/02_nav_history.csv")
aum = pd.read_csv(r"C:/Users/Admin/Desktop/Mutual_Fund_Analysis/data/processed/03_aum_by_fund_house.csv")
sip = pd.read_csv(r"C:/Users/Admin/Desktop/Mutual_Fund_Analysis/data/processed/04_monthly_sip_inflows.csv")
category = pd.read_csv(r"C:/Users/Admin/Desktop/Mutual_Fund_Analysis/data/processed/05_category_inflows.csv")
folio = pd.read_csv(r"C:/Users/Admin/Desktop/Mutual_Fund_Analysis/data/processed/06_industry_folio_count.csv")
performance = pd.read_csv(r"C:/Users/Admin/Desktop/Mutual_Fund_Analysis/data/processed/07_scheme_performance.csv")
transactions = pd.read_csv(r"C:/Users/Admin/Desktop/Mutual_Fund_Analysis/data/processed/08_investor_transactions.csv")
portfolio = pd.read_csv(r"C:/Users/Admin/Desktop/Mutual_Fund_Analysis/data/processed/09_portfolio_holdings.csv")
benchmark = pd.read_csv(r"C:/Users/Admin/Desktop/Mutual_Fund_Analysis/data/processed/10_benchmark_indices.csv")

# %%
nav.to_sql(
    "fact_nav",
    con=engine,
    if_exists="append",
    index=False,
    chunksize=5000
)

print("fact_nav loaded")
# Out:
# fact_nav loaded

# %%
aum.to_sql(
    "fact_aum",
    con=engine,
    if_exists="append",
    index=False
)

print("fact_aum loaded")
# Out:
# fact_aum loaded

# %%
sip.to_sql(
    "fact_sip_industry",
    con=engine,
    if_exists="append",
    index=False
)

print("fact_sip_industry loaded")
# Out:
# fact_sip_industry loaded

# %%
category.to_sql(
    "fact_category_inflows",
    con=engine,
    if_exists="append",
    index=False
)

print("fact_category_inflows loaded")
# Out:
# fact_category_inflows loaded

# %%
folio.to_sql(
    "fact_folio_count",
    con=engine,
    if_exists="append",
    index=False
)

print("fact_folio_count loaded")
# Out:
# fact_folio_count loaded

# %%
performance.to_sql(
    "fact_performance",
    con=engine,
    if_exists="append",
    index=False
)

print("fact_performance loaded")
# Out:
# fact_performance loaded

# %%
transactions.to_sql(
    "fact_transactions",
    con=engine,
    if_exists="append",
    index=False,
    chunksize=5000
)

print("fact_transactions loaded")
# Out:
# fact_transactions loaded

# %%
portfolio.to_sql(
    "fact_portfolio",
    con=engine,
    if_exists="append",
    index=False
)

print("fact_portfolio loaded")
# Out:
# fact_portfolio loaded

# %%
benchmark.to_sql(
    "fact_benchmark",
    con=engine,
    if_exists="append",
    index=False,
    chunksize=5000
)

print("fact_benchmark loaded")
# Out:
# fact_benchmark loaded
