# %% [markdown]
# # Performance Analytics
#
# ## 1. Data Loading
# ## 2. Daily Return Calculation
# ## 3. CAGR Analysis
# ## 4. Sharpe Ratio
# ## 5. Sortino Ratio
# ## 6. Alpha & Beta
# ## 7. Maximum Drawdown
# ## 8. Fund Scorecard
# ## 9. Benchmark Comparison
# ## 10. Key Findings

# %%
from sqlalchemy import create_engine

server = "laptop-t5cbj27g\SQLEXPRESS"
database = "Bluestock_MF"

engine = create_engine(
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
    "&trusted_connection=yes"
)

print("Connected Successfully")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11856\4091406864.py:3: SyntaxWarning: invalid escape sequence '\S'
#   server = "laptop-t5cbj27g\SQLEXPRESS"
# Connected Successfully

# %%
import pandas as pd
nav = pd.read_sql(
    """
    SELECT *
    FROM fact_nav
    """,
    engine
)

benchmark = pd.read_sql(
    """
    SELECT *
    FROM fact_benchmark
    """,
    engine
)

fund_master = pd.read_sql(
    """
    SELECT *
    FROM dim_fund
    """,
    engine
)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:1636: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   con = self.exit_stack.enter_context(con.connect())

# %%
nav = nav.sort_values(
    ['amfi_code','nav_date']
)
print(nav)
# Out:
#        nav_id  amfi_code    nav_date       nav
# 5750     5751     100016  2022-01-03  520.4608
# 5751     5752     100016  2022-01-04  515.0971
# 5752     5753     100016  2022-01-05  521.7239
# 5753     5754     100016  2022-01-06  515.7880
# 5754     5755     100016  2022-01-07  515.1639
# ...       ...        ...         ...       ...
# 45995   45996     149324  2026-05-25  292.4810
# 45996   45997     149324  2026-05-26  291.2707
# 45997   45998     149324  2026-05-27  288.8007
# 45998   45999     149324  2026-05-28  280.6873
# 45999   46000     149324  2026-05-29  279.7511
#
# [46000 rows x 4 columns]

# %%
nav['daily_return'] = (
    nav.groupby('amfi_code')['nav']
       .pct_change()
)
print(nav["daily_return"])
# Out:
# 5750          NaN
# 5751    -0.010306
# 5752     0.012865
# 5753    -0.011377
# 5754    -0.001210
#            ...
# 45995    0.012106
# 45996   -0.004138
# 45997   -0.008480
# 45998   -0.028093
# 45999   -0.003335
# Name: daily_return, Length: 46000, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))

sns.histplot(
    nav['daily_return'].dropna(),
    bins=100,
    kde=True
)

plt.title(
    "Distribution of Daily Returns"
)

plt.show()

# %%
def calculate_cagr(start_nav,
                   end_nav,
                   years):

    return (
        (end_nav/start_nav)
        ** (1/years)
        - 1
    ) * 100

# %%
cagr_table = []

for fund in nav['amfi_code'].unique():

    df = nav[
        nav['amfi_code']==fund
    ].sort_values('nav_date')

    start_nav = df.iloc[0]['nav']
    end_nav = df.iloc[-1]['nav']

    years = (
        (df['nav_date'].max()
         -
         df['nav_date'].min())
        .days
    ) / 365

    cagr = calculate_cagr(
        start_nav,
        end_nav,
        years
    )

    cagr_table.append(
        [fund,cagr]
    )

cagr_df = pd.DataFrame(
    cagr_table,
    columns=[
        'amfi_code',
        'cagr_pct'
    ]
)
print(cagr_df)
# Out:
#     amfi_code   cagr_pct
# 0      100016   2.635246
# 1      100025   4.455091
# 2      100033  30.099704
# 3      101206  23.520489
# 4      101207   7.933121
# 5      101208   6.504430
# 6      102885  18.218826
# 7      102886   1.170939
# 8      102887  16.828673
# 9      118632  24.031196
# 10     118633  16.262218
# 11     118634  16.361396
# 12     118635  15.945481
# 13     118636   5.313155
# 14     119092   6.363495
# 15     119093   7.891944
# 16     119094  28.192608
# 17     119095   1.520455
# 18     119120   5.885271
# 19     119551  25.784921
# 20     119552  21.508022
# 21     119598  32.398084
# 22     119599   2.053064
# 23     120503  18.771330
# 24     120504  23.277448
# 25     120505  32.801599
# 26     120506  17.072228
# 27     120507   7.232411
# 28     120841  13.522349
# 29     120842   6.696806
# 30     120843  30.883326
# 31     120844   6.910380
# 32     125497  19.003613
# 33     125498  11.293660
# 34     148567  30.949920
# 35     148568  22.499840
# 36     148569  31.924486
# 37     149322  13.383521
# 38     149323  29.558105
# 39     149324  32.262108

# %%
RF = 0.065

# %%
annual_return = (
    nav.groupby('amfi_code')
       ['daily_return']
       .mean()
       * 252
)

# %%
import numpy as np
annual_vol = (
    nav.groupby('amfi_code')
       ['daily_return']
       .std()
       * np.sqrt(252)
)
print(annual_vol)
# Out:
# amfi_code
# 100016    0.145481
# 100025    0.039052
# 100033    0.189367
# 101206    0.145682
# 101207    0.257973
# 101208    0.005064
# 102885    0.128366
# 102886    0.181346
# 102887    0.157584
# 118632    0.141484
# 118633    0.139972
# 118634    0.252415
# 118635    0.129832
# 118636    0.039855
# 119092    0.139507
# 119093    0.139833
# 119094    0.194071
# 119095    0.250666
# 119120    0.039671
# 119551    0.137414
# 119552    0.139394
# 119598    0.251406
# 119599    0.249501
# 120503    0.138844
# 120504    0.143638
# 120505    0.192909
# 120506    0.152305
# 120507    0.004939
# 120841    0.134638
# 120842    0.178947
# 120843    0.158870
# 120844    0.005133
# 125497    0.146689
# 125498    0.183524
# 148567    0.141937
# 148568    0.154291
# 148569    0.176740
# 149322    0.143539
# 149323    0.177462
# 149324    0.248402
# Name: daily_return, dtype: float64

# %%
sharpe = (
    annual_return - RF
) / annual_vol

# %%
sharpe_df = sharpe.reset_index()

sharpe_df.columns = [
    'amfi_code',
    'sharpe_ratio'
]
print(sharpe_df)
# Out:
#     amfi_code  sharpe_ratio
# 0      100016     -0.201517
# 1      100025     -0.567095
# 2      100033      1.093699
# 3      101206      1.027213
# 4      101207      0.162661
# 5      101208     -0.815567
# 6      102885      0.817099
# 7      102886     -0.205832
# 8      102887      0.619518
# 9      118632      1.081659
# 10     118633      0.645207
# 11     118634      0.448434
# 12     118635      0.664857
# 13     118636     -0.356630
# 14     119092      0.030785
# 15     119093      0.129614
# 16     119094      0.998231
# 17     119095     -0.075974
# 18     119120     -0.226575
# 19     119551      1.208267
# 20     119552      0.953279
# 21     119598      0.945308
# 22     119599     -0.057187
# 23     120503      0.797973
# 24     120504      1.026524
# 25     120505      1.180101
# 26     120506      0.648879
# 27     120507      0.495723
# 28     120841      0.494273
# 29     120842      0.076000
# 30     120843      1.306744
# 31     120844     -0.088747
# 32     125497      0.775790
# 33     125498      0.300612
# 34     148567      1.448291
# 35     148568      0.926287
# 36     148569      1.234930
# 37     149322      0.464037
# 38     149323      1.132122
# 39     149324      0.949796

# %%
downside = nav[
    nav['daily_return'] < 0
]

# %%
downside_std = (
    downside.groupby('amfi_code')
            ['daily_return']
            .std()
            * np.sqrt(252)
)

# %%
sortino = (
    annual_return - RF
) / downside_std
print(sortino)
# Out:
# amfi_code
# 100016   -0.351047
# 100025   -0.941821
# 100033    1.829134
# 101206    1.799563
# 101207    0.276644
# 101208   -1.681038
# 102885    1.435742
# 102886   -0.347222
# 102887    1.088755
# 118632    1.850133
# 118633    1.154476
# 118634    0.746015
# 118635    1.137977
# 118636   -0.613525
# 119092    0.052574
# 119093    0.221087
# 119094    1.703797
# 119095   -0.128186
# 119120   -0.376767
# 119551    2.140267
# 119552    1.609776
# 119598    1.675317
# 119599   -0.094387
# 120503    1.337943
# 120504    1.805294
# 120505    2.029353
# 120506    1.095895
# 120507    1.052124
# 120841    0.862574
# 120842    0.124693
# 120843    2.364320
# 120844   -0.187723
# 125497    1.330651
# 125498    0.508813
# 148567    2.385644
# 148568    1.632741
# 148569    2.146914
# 149322    0.762129
# 149323    1.875101
# 149324    1.619793
# Name: daily_return, dtype: float64

# %%
nifty100 = benchmark[
    benchmark['index_name']
    == 'NIFTY100'
]

# %%
nifty100 = nifty100.sort_values(
    'benchmark_date'
)

nifty100['benchmark_return'] = (
    nifty100['close_value']
    .pct_change()
)

# %%
from scipy.stats import linregress

# %%
alpha_beta = []

for fund in nav['amfi_code'].unique():

    fund_df = nav[
        nav['amfi_code']==fund
    ][['nav_date',
       'daily_return']]

    merged = fund_df.merge(
        nifty100[
            ['benchmark_date',
             'benchmark_return']
        ],
        left_on='nav_date',
        right_on='benchmark_date'
    )

    merged = merged.dropna()

    slope, intercept, r, p, stderr = linregress(
        merged['benchmark_return'],
        merged['daily_return']
    )

    alpha_beta.append([
        fund,
        intercept*252,
        slope
    ])

# %%
alpha_beta_df = pd.DataFrame(
    alpha_beta,
    columns=[
        'amfi_code',
        'alpha',
        'beta'
    ]
)
print(alpha_beta_df)
# Out:
#     amfi_code     alpha      beta
# 0      100016  0.037476 -0.058268
# 1      100025  0.042818  0.001158
# 2      100033  0.271954  0.005104
# 3      101206  0.213998  0.021086
# 4      101207  0.108971 -0.065289
# 5      101208  0.060861  0.000267
# 6      102885  0.170488 -0.019487
# 7      102886  0.028969 -0.042125
# 8      102887  0.162113  0.016683
# 9      118632  0.218294 -0.008354
# 10     118633  0.156438 -0.036639
# 11     118634  0.175007  0.103497
# 12     118635  0.151364 -0.001434
# 13     118636  0.050748  0.001257
# 14     119092  0.068995  0.009731
# 15     119093  0.082328  0.025883
# 16     119094  0.260767 -0.066265
# 17     119095  0.048016 -0.066951
# 18     119120  0.056209 -0.006414
# 19     119551  0.232010 -0.031751
# 20     119552  0.198686 -0.026159
# 21     119598  0.303370 -0.023196
# 22     119599  0.048824  0.062002
# 23     120503  0.177033 -0.040269
# 24     120504  0.211948  0.016232
# 25     120505  0.292636  0.000549
# 26     120506  0.162539  0.041896
# 27     120507  0.067462 -0.000444
# 28     120841  0.130429  0.036356
# 29     120842  0.078044  0.018057
# 30     120843  0.273305 -0.022830
# 31     120844  0.064557 -0.000401
# 32     125497  0.177298  0.048820
# 33     125498  0.119891  0.009054
# 34     148567  0.269838  0.023684
# 35     148568  0.208730 -0.026388
# 36     148569  0.282704  0.018134
# 37     149322  0.131732 -0.004050
# 38     149323  0.265986 -0.002523
# 39     149324  0.300579  0.011455

# %%
def max_drawdown(series):

    running_max = series.cummax()

    drawdown = (
        series/running_max
        - 1
    )

    return drawdown.min()

# %%
dd_results = []

for fund in nav['amfi_code'].unique():

    mdd = max_drawdown(
        nav[
            nav['amfi_code']==fund
        ]['nav']
    )

    dd_results.append(
        [fund,mdd]
    )
drawdown_df = pd.DataFrame(
    dd_results,
    columns=[
        'amfi_code',
        'max_drawdown'
    ]
)
print(drawdown_df)
# Out:
#     amfi_code  max_drawdown
# 0      100016     -0.247344
# 1      100025     -0.043083
# 2      100033     -0.162172
# 3      101206     -0.112916
# 4      101207     -0.354469
# 5      101208     -0.001622
# 6      102885     -0.108599
# 7      102886     -0.280011
# 8      102887     -0.215398
# 9      118632     -0.174141
# 10     118633     -0.186297
# 11     118634     -0.233449
# 12     118635     -0.116506
# 13     118636     -0.083164
# 14     119092     -0.144016
# 15     119093     -0.217514
# 16     119094     -0.209609
# 17     119095     -0.516778
# 18     119120     -0.043287
# 19     119551     -0.150124
# 20     119552     -0.118035
# 21     119598     -0.287060
# 22     119599     -0.525742
# 23     120503     -0.138979
# 24     120504     -0.125883
# 25     120505     -0.181885
# 26     120506     -0.198257
# 27     120507     -0.000977
# 28     120841     -0.175736
# 29     120842     -0.240035
# 30     120843     -0.129740
# 31     120844     -0.001163
# 32     125497     -0.152000
# 33     125498     -0.211173
# 34     148567     -0.112657
# 35     148568     -0.152726
# 36     148569     -0.163967
# 37     149322     -0.148446
# 38     149323     -0.172481
# 39     149324     -0.311719

# %%
scorecard = (
    cagr_df
    .merge(
        sharpe_df,
        on='amfi_code',
        how='inner'
    )
    .merge(
        alpha_beta_df,
        on='amfi_code',
        how='inner'
    )
    .merge(
        drawdown_df,
        on='amfi_code',
        how='inner'
    )
    .merge(
        fund_master[
            [
                'amfi_code',
                'expense_ratio_pct',
                'scheme_name'
            ]
        ],
        on='amfi_code',
        how='inner'
    )
)

# %%
scorecard.head()
# Out:
#    amfi_code   cagr_pct  sharpe_ratio     alpha      beta  max_drawdown  \
# 0     100016   2.635246     -0.201517  0.037476 -0.058268     -0.247344
# 1     100025   4.455091     -0.567095  0.042818  0.001158     -0.043083
# 2     100033  30.099704      1.093699  0.271954  0.005104     -0.162172
# 3     101206  23.520489      1.027213  0.213998  0.021086     -0.112916
# 4     101207   7.933121      0.162661  0.108971 -0.065289     -0.354469
#
#    expense_ratio_pct                                        scheme_name
# 0               1.55          HDFC Top 100 Fund - Regular Plan - Growth
# 1               0.56       HDFC Short Term Debt Fund - Regular - Growth
# 2               1.38  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 3               1.60      ABSL Frontline Equity Fund - Regular - Growth
# 4               1.53             ABSL Small Cap Fund - Regular - Growth

# %%
print("CAGR")
print(cagr_df.head())
print(cagr_df.columns)

print("\nSHARPE")
print(sharpe_df.head())
print(sharpe_df.columns)

print("\nALPHA BETA")
print(alpha_beta_df.head())
print(alpha_beta_df.columns)

print("\nDRAWDOWN")
print(drawdown_df.head())
print(drawdown_df.columns)
# Out:
# CAGR
#    amfi_code   cagr_pct
# 0     100016   2.635246
# 1     100025   4.455091
# 2     100033  30.099704
# 3     101206  23.520489
# 4     101207   7.933121
# Index(['amfi_code', 'cagr_pct'], dtype='object')
#
# SHARPE
#    amfi_code  sharpe_ratio
# 0     100016     -0.201517
# 1     100025     -0.567095
# 2     100033      1.093699
# 3     101206      1.027213
# 4     101207      0.162661
# Index(['amfi_code', 'sharpe_ratio'], dtype='object')
#
# ALPHA BETA
#    amfi_code     alpha      beta
# 0     100016  0.037476 -0.058268
# 1     100025  0.042818  0.001158
# 2     100033  0.271954  0.005104
# 3     101206  0.213998  0.021086
# 4     101207  0.108971 -0.065289
# Index(['amfi_code', 'alpha', 'beta'], dtype='object')
#
# DRAWDOWN
#    amfi_code  max_drawdown
# 0     100016     -0.247344
# 1     100025     -0.043083
# 2     100033     -0.162172
# 3     101206     -0.112916
# 4     101207     -0.354469
# Index(['amfi_code', 'max_drawdown'], dtype='object')

# %%
scorecard['return_rank'] = scorecard['cagr_pct'].rank(ascending=False)

scorecard['sharpe_rank'] = scorecard['sharpe_ratio'].rank(ascending=False)

scorecard['alpha_rank'] = scorecard['alpha'].rank(ascending=False)

scorecard['expense_rank'] = scorecard['expense_ratio_pct'].rank(ascending=True)

scorecard['drawdown_rank'] = scorecard['max_drawdown'].rank(ascending=False)

# %%
scorecard['raw_score'] = (
      0.30 * scorecard['return_rank']
    + 0.25 * scorecard['sharpe_rank']
    + 0.20 * scorecard['alpha_rank']
    + 0.15 * scorecard['expense_rank']
    + 0.10 * scorecard['drawdown_rank']
)

# %%
scorecard = scorecard.sort_values(
    'fund_score',
    ascending=False
)
print(scorecard)
# Out:
#     amfi_code   cagr_pct  sharpe_ratio     alpha      beta  max_drawdown  \
# 25     120505  32.801599      1.180101  0.292636  0.000549     -0.181885
# 34     148567  30.949920      1.448291  0.269838  0.023684     -0.112657
# 30     120843  30.883326      1.306744  0.273305 -0.022830     -0.129740
# 2      100033  30.099704      1.093699  0.271954  0.005104     -0.162172
# 36     148569  31.924486      1.234930  0.282704  0.018134     -0.163967
# 21     119598  32.398084      0.945308  0.303370 -0.023196     -0.287060
# 24     120504  23.277448      1.026524  0.211948  0.016232     -0.125883
# 20     119552  21.508022      0.953279  0.198686 -0.026159     -0.118035
# 39     149324  32.262108      0.949796  0.300579  0.011455     -0.311719
# 19     119551  25.784921      1.208267  0.232010 -0.031751     -0.150124
# 16     119094  28.192608      0.998231  0.260767 -0.066265     -0.209609
# 38     149323  29.558105      1.132122  0.265986 -0.002523     -0.172481
# 9      118632  24.031196      1.081659  0.218294 -0.008354     -0.174141
# 3      101206  23.520489      1.027213  0.213998  0.021086     -0.112916
# 32     125497  19.003613      0.775790  0.177298  0.048820     -0.152000
# 35     148568  22.499840      0.926287  0.208730 -0.026388     -0.152726
# 23     120503  18.771330      0.797973  0.177033 -0.040269     -0.138979
# 6      102885  18.218826      0.817099  0.170488 -0.019487     -0.108599
# 12     118635  15.945481      0.664857  0.151364 -0.001434     -0.116506
# 10     118633  16.262218      0.645207  0.156438 -0.036639     -0.186297
# 26     120506  17.072228      0.648879  0.162539  0.041896     -0.198257
# 27     120507   7.232411      0.495723  0.067462 -0.000444     -0.000977
# 11     118634  16.361396      0.448434  0.175007  0.103497     -0.233449
# 33     125498  11.293660      0.300612  0.119891  0.009054     -0.211173
# 31     120844   6.910380     -0.088747  0.064557 -0.000401     -0.001163
# 8      102887  16.828673      0.619518  0.162113  0.016683     -0.215398
# 37     149322  13.383521      0.464037  0.131732 -0.004050     -0.148446
# 15     119093   7.891944      0.129614  0.082328  0.025883     -0.217514
# 28     120841  13.522349      0.494273  0.130429  0.036356     -0.175736
# 13     118636   5.313155     -0.356630  0.050748  0.001257     -0.083164
# 18     119120   5.885271     -0.226575  0.056209 -0.006414     -0.043287
# 5      101208   6.504430     -0.815567  0.060861  0.000267     -0.001622
# 4      101207   7.933121      0.162661  0.108971 -0.065289     -0.354469
# 1      100025   4.455091     -0.567095  0.042818  0.001158     -0.043083
# 29     120842   6.696806      0.076000  0.078044  0.018057     -0.240035
# 14     119092   6.363495      0.030785  0.068995  0.009731     -0.144016
# 22     119599   2.053064     -0.057187  0.048824  0.062002     -0.525742
# 17     119095   1.520455     -0.075974  0.048016 -0.066951     -0.516778
# 0      100016   2.635246     -0.201517  0.037476 -0.058268     -0.247344
# 7      102886   1.170939     -0.205832  0.028969 -0.042125     -0.280011
#
#     expense_ratio_pct                                        scheme_name  \
# 25               1.36           ICICI Pru Midcap Fund - Regular - Growth
# 34               1.46      Mirae Asset Large Cap Fund - Regular - Growth
# 30               1.45             Kotak Flexicap Fund - Regular - Growth
# 2                1.38  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 36               1.60      Mirae Asset Tax Saver Fund - Regular - Growth
# 21               1.43         SBI Small Cap Fund - Regular Plan - Growth
# 24               0.80          ICICI Pru Bluechip Fund - Direct - Growth
# 20               0.66           SBI Bluechip Fund - Direct Plan - Growth
# 39               1.52              DSP Small Cap Fund - Regular - Growth
# 19               1.54          SBI Bluechip Fund - Regular Plan - Growth
# 16               1.38                Axis Midcap Fund - Regular - Growth
# 38               1.61                 DSP Midcap Fund - Regular - Growth
# 9                1.51     Nippon India Large Cap Fund - Regular - Growth
# 3                1.60      ABSL Frontline Equity Fund - Regular - Growth
# 32               0.92           HDFC Top 100 Fund - Direct Plan - Growth
# 35               1.52  Mirae Asset Emerging Bluechip Fund - Regular -...
# 23               1.42         ICICI Pru Bluechip Fund - Regular - Growth
# 6                1.57         UTI Nifty 50 Index Fund - Regular - Growth
# 12               0.89                     Nippon India ETF Nifty 50 BeES
# 10               0.72      Nippon India Large Cap Fund - Direct - Growth
# 26               1.41  ICICI Pru Value Discovery Fund - Regular - Growth
# 27               0.74           ICICI Pru Liquid Fund - Regular - Growth
# 11               1.53     Nippon India Small Cap Fund - Regular - Growth
# 33               0.78  HDFC Mid-Cap Opportunities Fund - Direct - Growth
# 31               0.60               Kotak Liquid Fund - Regular - Growth
# 8                1.64              UTI Flexi Cap Fund - Regular - Growth
# 37               1.54         DSP Top 100 Equity Fund - Regular - Growth
# 15               0.75               Axis Bluechip Fund - Direct - Growth
# 28               1.59             Kotak Bluechip Fund - Regular - Growth
# 13               0.55  Nippon India Gilt Securities Fund - Regular - ...
# 18               0.77       SBI Magnum Gilt Fund - Regular Plan - Growth
# 5                0.79                ABSL Liquid Fund - Regular - Growth
# 4                1.53             ABSL Small Cap Fund - Regular - Growth
# 1                0.56       HDFC Short Term Debt Fund - Regular - Growth
# 29               1.56      Kotak Emerging Equity Fund - Regular - Growth
# 14               1.64              Axis Bluechip Fund - Regular - Growth
# 22               0.72          SBI Small Cap Fund - Direct Plan - Growth
# 17               1.38             Axis Small Cap Fund - Regular - Growth
# 0                1.55          HDFC Top 100 Fund - Regular Plan - Growth
# 7                1.51                UTI Mid Cap Fund - Regular - Growth
#
#     return_rank  sharpe_rank  alpha_rank  expense_rank  drawdown_rank  \
# 25          1.0          5.0         3.0          15.0           25.0
# 34          5.0          1.0         7.0          23.0            8.0
# 30          6.0          2.0         5.0          22.0           13.0
# 2           7.0          7.0         6.0          17.0           20.0
# 36          4.0          3.0         4.0          36.5           21.0
# 21          2.0         14.0         1.0          21.0           36.0
# 24         13.0         10.0        13.0          12.0           12.0
# 20         15.0         12.0        15.0           4.0           11.0
# 39          3.0         13.0         2.0          26.5           37.0
# 19         10.0          4.0        10.0          30.5           17.0
# 16          9.0         11.0         9.0          17.0           28.0
# 38          8.0          6.0         8.0          38.0           22.0
# 9          11.0          8.0        11.0          24.5           23.0
# 3          12.0          9.0        12.0          36.5            9.0
# 32         16.0         18.0        16.0          14.0           18.0
# 35         14.0         15.0        14.0          26.5           19.0
# 23         17.0         17.0        17.0          20.0           14.0
# 6          18.0         16.0        19.0          34.0            7.0
# 12         23.0         19.0        23.0          13.0           10.0
# 10         22.0         21.0        22.0           5.5           26.0
# 26         19.0         20.0        20.0          19.0           27.0
# 27         29.0         23.0        31.0           7.0            1.0
# 11         21.0         26.0        18.0          28.5           32.0
# 33         26.0         27.0        26.0          10.0           29.0
# 31         30.0         34.0        32.0           3.0            2.0
# 8          20.0         22.0        21.0          39.5           30.0
# 37         25.0         25.0        24.0          30.5           16.0
# 15         28.0         29.0        28.0           8.0           31.0
# 28         24.0         24.0        25.0          35.0           24.0
# 13         35.0         38.0        35.0           1.0            6.0
# 18         34.0         37.0        34.0           9.0            5.0
# 5          32.0         40.0        33.0          11.0            3.0
# 4          27.0         28.0        27.0          28.5           38.0
# 1          36.0         39.0        38.0           2.0            4.0
# 29         31.0         30.0        29.0          33.0           33.0
# 14         33.0         31.0        30.0          39.5           15.0
# 22         38.0         32.0        36.0           5.5           40.0
# 17         39.0         33.0        37.0          17.0           39.0
# 0          37.0         35.0        39.0          32.0           34.0
# 7          40.0         36.0        40.0          24.5           35.0
#
#     raw_score  fund_score
# 25      6.900  100.000000
# 34      7.400   98.292058
# 30      7.900   96.584116
# 2       9.600   90.777114
# 36     10.325   88.300598
# 21     11.050   85.824082
# 24     12.000   82.578992
# 20     12.200   81.895816
# 39     12.225   81.810418
# 19     12.275   81.639624
# 16     12.600   80.529462
# 38     13.400   77.796755
# 9      13.475   77.540564
# 3      14.625   73.612297
# 32     16.400   67.549103
# 35     16.625   66.780529
# 23     17.150   64.987190
# 6      19.000   58.667805
# 12     19.200   57.984629
# 10     19.675   56.362084
# 26     20.250   54.397950
# 27     21.800   49.103330
# 11     23.875   42.015371
# 33     24.150   41.076003
# 31     24.550   39.709650
# 8      24.625   39.453459
# 37     24.725   39.111870
# 15     25.550   36.293766
# 28     25.850   35.269001
# 13     27.750   28.778822
# 18     28.100   27.583262
# 5      28.150   27.412468
# 4      28.575   25.960717
# 1      28.850   25.021349
# 29     30.850   18.189582
# 14     31.075   17.421008
# 22     31.425   16.225448
# 17     33.800    8.112724
# 0      35.850    1.110162
# 7      36.175    0.000000

# %%
scorecard.to_csv(
    "fund_scorecard.csv",
    index=False
)

# %%
alpha_beta_df.to_csv(
    "alpha_beta.csv",
    index=False
)

# %%
top5_funds = (
    scorecard
    .head(5)
    ['amfi_code']
    .tolist()
)

top5_funds
# Out:
# [100016, 100025, 100033, 101206, 101207]

# %%
top5_nav = nav[
    nav['amfi_code'].isin(top5_funds)
].copy()

# %%
top5_nav = top5_nav.merge(
    fund_master[
        ['amfi_code','scheme_name']
    ],
    on='amfi_code'
)

# %%
top5_nav['normalized_nav'] = (
    top5_nav.groupby('amfi_code')['nav']
    .transform(
        lambda x: x / x.iloc[0] * 100
    )
)

# %%
benchmarks = benchmark[
    benchmark['index_name'].isin(
        ['NIFTY50','NIFTY100']
    )
].copy()

# %%
benchmarks['normalized_value'] = (
    benchmarks.groupby('index_name')['close_value']
    .transform(
        lambda x: x / x.iloc[0] * 100
    )
)

# %%
benchmark_plot = benchmarks[
    [
        'benchmark_date',
        'index_name',
        'normalized_value'
    ]
].copy()

benchmark_plot.columns = [
    'date',
    'name',
    'value'
]

# %%
fund_plot = top5_nav[
    [
        'nav_date',
        'scheme_name',
        'normalized_nav'
    ]
].copy()

fund_plot.columns = [
    'date',
    'name',
    'value'
]

# %%
comparison_df = pd.concat(
    [
        fund_plot,
        benchmark_plot
    ]
)

# %%
import plotly.express as px

fig = px.line(
    comparison_df,
    x='date',
    y='value',
    color='name',
    title='Top 5 Funds vs NIFTY50 and NIFTY100'
)

fig.show()

# %%
fig.write_image(
    "benchmark_comparison.png",
    width=1400,
    height=800
)
